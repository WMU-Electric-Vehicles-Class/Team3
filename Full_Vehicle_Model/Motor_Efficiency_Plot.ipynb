# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np
import pandas as pd
from scipy.interpolate import LinearNDInterpolator
from matplotlib import pyplot as plt

# %%
front = pd.read_csv("Audi_e_Tron_Motors_ResultsForMaps.xlsx - APA250-Maps.csv")
front
# Out:
#     SPEED [rad/s]  TORQUE [Nm]   EFFY [%]  JLossTot [W]  Unnamed: 4      SLIP  \
# 0       13.217688    21.938861   3.623169   7705.256861         NaN  9.816327
# 1       18.689936     3.570540  64.226239     34.434394         NaN  6.142857
# 2       23.650243    48.618619   4.427373  24803.651850         NaN  9.632653
# 3       24.140825    14.169394  51.699565    309.962349         NaN  5.959184
# 4       41.550011     6.130481  70.645493     93.364720         NaN  2.102041
# ..            ...          ...        ...           ...         ...       ...
# 93    1464.520017    26.698920  97.422274    768.797547         NaN  1.000000
# 94    1479.200051    16.239395  97.398176    471.905172         NaN  1.000000
# 95    1499.602811     9.132883  97.363883    269.034125         NaN  1.000000
# 96    1514.282845     3.657322  97.284527    109.056572         NaN  1.000000
# 97    1549.365638    38.949840  97.454238   1184.849909         NaN  1.000000
#
# ...

# %%
x = front["SPEED [rad/s]"]
y = front["TORQUE [Nm]"]
z = front["EFFY [%]"]

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=90, azim=-90)

surf = ax.plot_trisurf(x, y, z, cmap="viridis", linewidth=0)
ax.set_xlabel('Speed (rad/s)', fontsize=15, rotation=150)
ax.set_ylabel('Torque (Nm)',fontsize = 15, rotation = 150)
# Out:
# Text(0.5, 0, 'Torque (Nm)')
